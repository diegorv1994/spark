# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
appName = "opi"
spark = SparkSession \
    .builder \
    .appName(appName) \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

dfSchema = StructType([
  StructField("producto", StringType(), False),
  StructField("presentacion", StringType(), False),
  StructField("marca", StringType(), False),
  StructField("categoria", StringType(), False),
  StructField("catalogo", StringType(), False),
  StructField("precio", FloatType(), False),
  StructField("fechaRegistro", StringType(), False),
  StructField("cadenaComercial", StringType(), False),
  StructField("giro", StringType(), False),
  StructField("nombreComercial", StringType(), False),
  StructField("direccion", StringType(), False),
  StructField("estado", StringType(), False),
  StructField("municipio", StringType(), False),
  StructField("latitud", FloatType(), False),
  StructField("longitud", FloatType(), False)
])

# %%
#import pandas as pd
#df = pd.read_csv('all_data.csv')
#df.to_parquet('output.parquet')

# %%
df = spark.read.csv('all_data.csv',schema=dfSchema, header=True)

# %%
df.write.mode('overwrite').parquet("all_data.parquet")

# %%
df.show(5)

# %% [markdown]
# Procesamiento de los datos
#
# a. ¿Cuántos registros hay?

# %%
#Cuenta el número de filas de nuestra dataframe
num_rows = df.count()
print("número de registros: ", num_rows)
# Out:
# número de registros:  62530715

# %% [markdown]
# b. ¿Cuántas categorías?

# %%
lst_1=df.select('categoria').distinct().collect()

# %%
lst_1
# Out:
# [Row(categoria='MATERIAL ESCOLAR'),
#  Row(categoria='ARTS. PARA EL CUIDADO PERSONAL'),
#  Row(categoria='PESCADOS Y MARISCOS EN CONSERVA'),
#  Row(categoria='UTENSILIOS DOMESTICOS'),
#  Row(categoria='categoria'),
#  Row(categoria='DETERGENTES Y PRODUCTOS SIMILARES'),
#  Row(categoria='CARNE Y VISCERAS DE RES'),
#  Row(categoria='PRODUCTOS DE TEMPORADA (NAVIDEÐOS)'),
#  Row(categoria='GALLETAS PASTAS Y HARINAS DE TRIGO'),
#  Row(categoria='HORTALIZAS FRESCAS'),
#  Row(categoria=None),
#  Row(categoria='DERIVADOS DE LECHE'),
#  Row(categoria='TORTILLAS Y DERIVADOS DEL MAIZ'),
#  Row(categoria='GRASAS ANIMALES COMESTIBLES'),
#  Row(categoria='APARATOS ELECTRONICOS'),
#  Row(categoria='LEGUMBRES SECAS'),
#  Row(categoria='CAFE'),
#  Row(categoria='MUEBLES DE COCINA'),
#  Row(categoria='CARNES FRIAS SECAS Y EMBUTIDOS'),
#  Row(categoria='CHOCOLATES Y GOLOSINAS'),
#  Row(categoria='PAN'),
#  Row(categoria='CERVEZA'),
#  Row(categoria='MEDICAMENTOS'),
#  Row(categoria='CONDIMENTOS'),
#  Row(categoria='REFRESCOS ENVASADOS'),
#  Row(categoria='ACEITES Y GRASAS VEG. COMESTIBLES'),
#  Row(categoria='TE'),
#  Row(categoria='PESCADOS Y MARISCOS'),
#  Row(categoria='CARNE DE AVE'),
#  Row(categoria='FRUTAS Y LEGUMBRES PROCESADAS'),
#  Row(categoria='VINOS Y LICORES'),
#  Row(categoria='CARNE Y VISCERAS DE CERDO'),
#  Row(categoria='ACCESORIOS DOMESTICOS'),
#  Row(categoria='FRUTAS FRESCAS'),
#  Row(categoria='ARROZ Y CEREALES PREPARADOS'),
#  Row(categoria='APARATOS ELECTRICOS'),
#  Row(categoria='ARTS. DE ESPARCIMIENTO (JUGUETES)'),
#  Row(categoria='CIGARRILLOS'),
#  Row(categoria='HUEVO'),
#  Row(categoria='LECHE PROCESADA'),
#  Row(categoria='AZUCAR'),
#  Row(categoria='ARTS. DE PAPEL P/HIGIENE PERSONAL')]

# %%
len(lst_1)
# Out:
# 42

# %% [markdown]
# Hay 40 categorías porque None y categoria no son categorías

# %% [markdown]
# c. ¿Cuántas cadenas comerciales están siendo monitoreadas?

# %%
lst_2=df.select('cadenaComercial').distinct().collect()

# %%
lst_2
# Out:
# [Row(cadenaComercial='JULIO CEPEDA JUGUETERIAS'),
#  Row(cadenaComercial='WOOLWORTH'),
#  Row(cadenaComercial='MARISCOS LA SEPTIMA'),
#  Row(cadenaComercial='PAPELERIA EL TINTERO'),
#  Row(cadenaComercial='LIBRERIA DE SANCHO PANZA'),
#  Row(cadenaComercial='PAPELERIA Y LIBRERIA SAN MIGUEL'),
#  Row(cadenaComercial='PLAZA DEL LIBRO'),
#  Row(cadenaComercial='MERCADO ALONSO FELIPE DE ANDRADE'),
#  Row(cadenaComercial='MERCADO LA CRUZ'),
#  Row(cadenaComercial='ZAPATERIA PAKAR'),
#  Row(cadenaComercial='SIGUBA'),
#  Row(cadenaComercial='MEGA TOYS'),
#  Row(cadenaComercial='MARISCOS VILLA AZUL'),
#  Row(cadenaComercial='BODEGAS VICTORIA'),
#  Row(cadenaComercial='MINISUPER INALA'),
#  Row(cadenaComercial='S MART'),
#  Row(cadenaComercial='LIBRERIA ATHENAS'),
#  Row(cadenaComercial='FARMACIAS M+'),
#  Row(cadenaComercial='MUEBLERIA CREDILAND'),
#  Row(cadenaComercial='LOYEP (UNIFORMES)'),
#  Row(cadenaComercial='FARMACIAS SAN FRANCISCO DE ASIS'),
#  Row(cadenaComercial='PESCADERIA TAMPIQUEÑOS'),
#  Row(cadenaComercial='PESCADERIA GUASAVEÑA'),
#  Row(cadenaComercial='PESCADERÍA COMERCIALIZADORA DEL MAR'),
#  Row(cadenaComercial='MERKABASTOS'),
#  Row(cadenaComercial='PAPELERIA EL ESCRITORIO'),
#  Row(cadenaComercial='PAPELERIA COLIBRI'),
#  Row(cadenaComercial='PESCADERIA EL POPULAR ELIAS'),
#  Row(cadenaComercial='MERCADO LAZARO CARDENAS'),
#  Row(cadenaComercial='SUPER 7'),
#  Row(cadenaComercial='PAPELERIA POPULAR'),
#  Row(cadenaComercial='RYSE'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS MIGUEL HIDAGO'),
#  Row(cadenaComercial='UNIFORMES LUCE'),
#  Row(cadenaComercial='MERCADO PLUTARCO MONTIEL'),
#  Row(cadenaComercial='ARIES'),
#  Row(cadenaComercial='LIBRERIA UNIVERSAL DE AGUASCALIENTES'),
#  Row(cadenaComercial='LA CASTELLANA'),
#  Row(cadenaComercial='FARMACIA DURANGO'),
#  Row(cadenaComercial='FARMACIA CANTO'),
#  Row(cadenaComercial='JUGUETERIA Y PAPELERIA TONY'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS PLOMADA'),
#  Row(cadenaComercial='MERCADO EXPRESS SORIANA'),
#  Row(cadenaComercial='MI TIENDA DEL AHORRO'),
#  Row(cadenaComercial='PESCADERIA DISTRIBUIDORA GUASAVE'),
#  Row(cadenaComercial='CIRCULO K'),
#  Row(cadenaComercial='ABARROTES APIZACO'),
#  Row(cadenaComercial='SUPER LEY'),
#  Row(cadenaComercial='SMART & FINAL DEL NOROESTE'),
#  Row(cadenaComercial='SUPER MAZ'),
#  Row(cadenaComercial='FARMACON'),
#  Row(cadenaComercial='CALIMAX'),
#  Row(cadenaComercial='AUTOSERVICIO GUTIERREZ RIZO'),
#  Row(cadenaComercial='SUPER LILI'),
#  Row(cadenaComercial='PESCADERIA PARGUITA REYNA'),
#  Row(cadenaComercial='UNIFORMES ESTTELA'),
#  Row(cadenaComercial='LIBRERIA NOROESTE'),
#  Row(cadenaComercial='GIGANTE'),
#  Row(cadenaComercial='FARMACIA ABC'),
#  Row(cadenaComercial='ABARROTES VIRGO'),
#  Row(cadenaComercial='PESCADERIA BAHIA KINO'),
#  Row(cadenaComercial='FARMACIA SAN PABLO'),
#  Row(cadenaComercial='EL BODEGON'),
#  Row(cadenaComercial='FARMACIA GUANAJUATO'),
#  Row(cadenaComercial='FARMACIAS EL FENIX'),
#  Row(cadenaComercial='FARMACIA GEMS DE DESCUENTO'),
#  Row(cadenaComercial='ZAPOPAN ESCOLAR'),
#  Row(cadenaComercial='RAC'),
#  Row(cadenaComercial='MERCADO BENITO JUAREZ'),
#  Row(cadenaComercial='MERCADO ADOLFO LOPEZ MATEOS'),
#  Row(cadenaComercial='PAPELERIA DABO'),
#  Row(cadenaComercial='LIBRERIA MEXICO DEL PACIFICO'),
#  Row(cadenaComercial='UNIFORMES UNIKA'),
#  Row(cadenaComercial='LIBRERIA Y PAPELERIA DEL MAESTRO'),
#  Row(cadenaComercial='FARMACIA LOPEZ'),
#  Row(cadenaComercial='MERCADO MIGUEL HIDALGO'),
#  Row(cadenaComercial='HEMSA'),
#  Row(cadenaComercial='PAPELERIA SIN NOMBRE'),
#  Row(cadenaComercial='FARMACIA MADIR'),
#  Row(cadenaComercial='PAPELERIA ABC'),
#  Row(cadenaComercial='PAPELERIA LA FUERZA'),
#  Row(cadenaComercial='MINISUPER FRUTERIA NUEVO SAN LUIS'),
#  Row(cadenaComercial='MERCADO FELIPE ANGELES'),
#  Row(cadenaComercial='GAME PLANET'),
#  Row(cadenaComercial='MARISCOS LA ESTRELLA'),
#  Row(cadenaComercial='ZAPATERIA CHARLY'),
#  Row(cadenaComercial='MILANO'),
#  Row(cadenaComercial='PAPELERIAS SUPER PRECIOS'),
#  Row(cadenaComercial='FARMACIA SAN PEDRO'),
#  Row(cadenaComercial='MERCADO CENTRALITO'),
#  Row(cadenaComercial='PESCADERIA GOLFO DE MEXICO'),
#  Row(cadenaComercial='PAPELERIA DEL ESTUDIANTE'),
#  Row(cadenaComercial='PAPELERIA SARACHO'),
#  Row(cadenaComercial='LIBRERIA DE CARSA'),
#  Row(cadenaComercial='PESCADERIA EL FORO'),
#  Row(cadenaComercial='ULTRA HOGAR'),
#  Row(cadenaComercial='ZAPATERIA COPPEL CANADA'),
#  Row(cadenaComercial='ABARROTES SUPER RIVERA'),
#  Row(cadenaComercial='DEL SOL'),
#  Row(cadenaComercial='COMERCIAL DE AGUA PRIETA'),
#  Row(cadenaComercial='PANADERIAS TRADICIONALES'),
#  Row(cadenaComercial='MUEBLERIA FABRICAS DE FRANCIA'),
#  Row(cadenaComercial='MERCADO GARMENDIA'),
#  Row(cadenaComercial='CITY MARKET'),
#  Row(cadenaComercial='FARMACIA VIPS'),
#  Row(cadenaComercial='PAPELERIA CANCUN'),
#  Row(cadenaComercial='MAGADAN'),
#  Row(cadenaComercial='LA MODERNA (PAPELERIALA)'),
#  Row(cadenaComercial='FARMACIA PLAZA'),
#  Row(cadenaComercial='MUEBLERIA ELIZONDO'),
#  Row(cadenaComercial='PAPELERIA MASAN'),
#  Row(cadenaComercial='NOVA LUXE'),
#  Row(cadenaComercial='MERCADO CONSTITUCION'),
#  Row(cadenaComercial='CENTRAL DE ABASTOS'),
#  Row(cadenaComercial='CENTRO NACIONAL DE DISTRIBUCION JUTEGA'),
#  Row(cadenaComercial='SORIANA'),
#  Row(cadenaComercial='UNIFORMES ALMACENES GARCIA'),
#  Row(cadenaComercial='PAPELERIA ESCOLAR DE PUEBLA'),
#  Row(cadenaComercial='BODEGA AURRERA EXPRESS'),
#  Row(cadenaComercial='VINOS Y LICORES LA CONQUISTA'),
#  Row(cadenaComercial='PAPELERIA MATTY S'),
#  Row(cadenaComercial='LIBRERIA BALLENITA'),
#  Row(cadenaComercial='PALACIO DE HIERRO'),
#  Row(cadenaComercial='PAPELERIA SAN FELIPE'),
#  Row(cadenaComercial='LIBROS EDUCATIVOS'),
#  Row(cadenaComercial='LIBRERIA LIBRO CENTRO'),
#  Row(cadenaComercial='MERCADO SORIANA'),
#  Row(cadenaComercial='FARMACIA IDEAL'),
#  Row(cadenaComercial='SALINAS Y ROCHA'),
#  Row(cadenaComercial='U.N.A.M.'),
#  Row(cadenaComercial='FARMACIA CRUZ ROSA'),
#  Row(cadenaComercial='PESCADERIA EL MALECON'),
#  Row(cadenaComercial='DEPARTAMENTAL DEL SOL'),
#  Row(cadenaComercial='VINOTECA'),
#  Row(cadenaComercial='ORGANIZACION PAPELERA MEXICANA'),
#  Row(cadenaComercial='SUPER MERCADO ARAMBURO'),
#  Row(cadenaComercial='BOTICA KENT TLAXCALA'),
#  Row(cadenaComercial='SUPER KOMPRAS'),
#  Row(cadenaComercial='PAPELERIA ALBERTO PLIEGO DG E HIJOS'),
#  Row(cadenaComercial='FARMACIAS GI'),
#  Row(cadenaComercial='FARMACIA SANCHEZ'),
#  Row(cadenaComercial='LIBRERIA IMAGEN DE TOLUCA'),
#  Row(cadenaComercial='PESCADERIA EXPENDIO LOS RUFINOS'),
#  Row(cadenaComercial='PESCADERIA LA AMISTAD'),
#  Row(cadenaComercial='BENAVIDES'),
#  Row(cadenaComercial='PESCADERIA CEPESMAR'),
#  Row(cadenaComercial='FARMACIA SANTA CECILIA'),
#  Row(cadenaComercial='PAPELERIA JORTUSA'),
#  Row(cadenaComercial='PESCADERIA EL TEJANO DE QUERETARO'),
#  Row(cadenaComercial='PAPELERIA REVOLUCION'),
#  Row(cadenaComercial='CENTRAL PAP'),
#  Row(cadenaComercial='PESCADERIA EL BARQUITO'),
#  Row(cadenaComercial='UNIFORMES TROFEO'),
#  Row(cadenaComercial='MERCO'),
#  Row(cadenaComercial='BECERRIL AIR'),
#  Row(cadenaComercial='LA COSTA MARISQUERA'),
#  Row(cadenaComercial='PAPELERIA LA LITERARIA'),
#  Row(cadenaComercial='ZAPATERIA 3 HERMANOS'),
#  Row(cadenaComercial='FARMACIA'),
#  Row(cadenaComercial='LIBRERIA LA CULTURA'),
#  Row(cadenaComercial=None),
#  Row(cadenaComercial='FARM. DE SUPERAHORRO HDEZ. DE CHIH,SA CV'),
#  Row(cadenaComercial='PAPELERIA  BIZMART'),
#  Row(cadenaComercial='MERCADO  GENERAL EMILIANO ZAPATA SALAZAR'),
#  Row(cadenaComercial='SUPER ISSSTE'),
#  Row(cadenaComercial='FARMACIA CABALLERO'),
#  Row(cadenaComercial='PAPELERIA JALISCO'),
#  Row(cadenaComercial='MERCADO ALCALDE'),
#  Row(cadenaComercial='MERCADO ABASTOS'),
#  Row(cadenaComercial='SUFARMEX'),
#  Row(cadenaComercial='FARMACIA SANTO DOMINGO'),
#  Row(cadenaComercial='MINISUPER LA GLORIA'),
#  Row(cadenaComercial='PESCADERIA GANDARA'),
#  Row(cadenaComercial='THE B STORE'),
#  Row(cadenaComercial='TIENDA DE ABARROTES'),
#  Row(cadenaComercial='OFFICE DEPOT'),
#  Row(cadenaComercial='SORIANA SUPER'),
#  Row(cadenaComercial='TENIS MENDEZ RUIZ'),
#  Row(cadenaComercial='LIBRERIA ZAPLANA'),
#  Row(cadenaComercial='PESCADERIA LA MARISQUERIA DEL 23'),
#  Row(cadenaComercial='PAPELERIA CONTI'),
#  Row(cadenaComercial='PAPELERIA Y LIBRERIA SAGRADO CORAZON'),
#  Row(cadenaComercial='MINISUPER DULCE GLORIA'),
#  Row(cadenaComercial='PAPELERIA EL ARTILLERO'),
#  Row(cadenaComercial='LA COMER'),
#  Row(cadenaComercial='PAPELERIA DELTA'),
#  Row(cadenaComercial='ZAPATERIA TLAXCALA'),
#  Row(cadenaComercial='PESCADERIA QUETZALCOATL'),
#  Row(cadenaComercial='MUEBLERIA CENTRAL'),
#  Row(cadenaComercial='MERCADO 12 DE MAYO'),
#  Row(cadenaComercial='MERCADO PEDRO SAINZ DE BARANDA'),
#  Row(cadenaComercial='MUEBLERIAS EL GALLO'),
#  Row(cadenaComercial='FAMSA'),
#  Row(cadenaComercial='PAPELERIA OSCAR'),
#  Row(cadenaComercial='PROHOGAR'),
#  Row(cadenaComercial='MERCADO JUAREZ'),
#  Row(cadenaComercial='CRISTALERIA LA VIOLETA'),
#  Row(cadenaComercial='MERCADO PUBLICO 27 DE FEBRERO'),
#  Row(cadenaComercial='FARMACIAS ISSSTE'),
#  Row(cadenaComercial='FARMACIA SANTA FE'),
#  Row(cadenaComercial='COMERCIAL V H'),
#  Row(cadenaComercial='FARMACIA SAN JOSE'),
#  Row(cadenaComercial='ELECTRODOMESTICOS CHAPUR'),
#  Row(cadenaComercial='ZAPATERIA LA RIVERA'),
#  Row(cadenaComercial='PESCADERIAS TRADICIONALES'),
#  Row(cadenaComercial='MERCADO SANDERS'),
#  Row(cadenaComercial='FARMACIA CUERNAVACA'),
#  Row(cadenaComercial='PESCADERIA EL PATON'),
#  Row(cadenaComercial='HERMANOS VAZQUEZ'),
#  Row(cadenaComercial='PESCADERIA CANTAMAR'),
#  Row(cadenaComercial='FARMACIA MADERO'),
#  Row(cadenaComercial='VINOS Y LICORES MAGADAN QUIMIA'),
#  Row(cadenaComercial='PESCADERIA PACIFICO'),
#  Row(cadenaComercial='FARMACIA DE DIOS'),
#  Row(cadenaComercial='UNIFORMES MARUSA'),
#  Row(cadenaComercial='EXTRA'),
#  Row(cadenaComercial='PAPELERIA DANY'),
#  Row(cadenaComercial='PAPELERIA AL FERROCARRIL'),
#  Row(cadenaComercial='PAPELERIA CUAUTLA'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS DON LEO'),
#  Row(cadenaComercial='FARMACIA HIDALGO'),
#  Row(cadenaComercial='SUPERMERCADOS SANTA FE'),
#  Row(cadenaComercial='LA CUBIELLA'),
#  Row(cadenaComercial='PESCADERIA LA BARCA'),
#  Row(cadenaComercial='PAPELERIA SAN JOSE'),
#  Row(cadenaComercial='UNIFORMES ALMACENES SANTA CRUZ'),
#  Row(cadenaComercial='FARMACIA LA MAS BARATA'),
#  Row(cadenaComercial='BODEGA AURRERA'),
#  Row(cadenaComercial='UNIFORMES COTICA'),
#  Row(cadenaComercial='FARMACIA HOSPITAL REFORMA'),
#  Row(cadenaComercial='TENIS DEL CARMEN'),
#  Row(cadenaComercial='BLOCKBUSTER'),
#  Row(cadenaComercial='PESCADERIA LA NUEVA'),
#  Row(cadenaComercial='LA FUENTE (VINATERIA)'),
#  Row(cadenaComercial='DUNOSUSA'),
#  Row(cadenaComercial='PAPELERIA GONVIL'),
#  Row(cadenaComercial='VINOS Y LICORES EL REY'),
#  Row(cadenaComercial='FARMACIA LUMIG'),
#  Row(cadenaComercial='PESCADERIA SEVILLA CARRO VERDE'),
#  Row(cadenaComercial='JUGUETERIA JUGUETIMUNDO'),
#  Row(cadenaComercial='UNIFORMES EL LEON'),
#  Row(cadenaComercial='UNIFORMES EL NUEVO MUNDO'),
#  Row(cadenaComercial='PAPELERIA ALAMEDA'),
#  Row(cadenaComercial='SUPER AKI XTRA'),
#  Row(cadenaComercial='BEST BUY'),
#  Row(cadenaComercial='MUEBLERIA FOTO CONTINO'),
#  Row(cadenaComercial='PESCADERIA LAS TRUCHAS'),
#  Row(cadenaComercial='UNIFORMES CASA SUSI'),
#  Row(cadenaComercial='GAME RUSH'),
#  Row(cadenaComercial='SUPER AMIGO'),
#  Row(cadenaComercial='MERCADO DEL MAR SAN FELIPE'),
#  Row(cadenaComercial='FARMACIA PROVIDENCIA'),
#  Row(cadenaComercial='PAPELERIA FOX'),
#  Row(cadenaComercial='FARMACIA BAZAR'),
#  Row(cadenaComercial='PAPELERIA CASA SAKURA'),
#  Row(cadenaComercial='SUPERMERCADO OJINAGA'),
#  Row(cadenaComercial='TIENDA POPULAR'),
#  Row(cadenaComercial='FARMACIA DE SIMILARES'),
#  Row(cadenaComercial='NETO (SUPER PRECIO)'),
#  Row(cadenaComercial='FARMACIA AZTECA'),
#  Row(cadenaComercial='MUEBLERIA TELESERVI'),
#  Row(cadenaComercial='FARMACIAS DEL ROSARIO'),
#  Row(cadenaComercial='LA MARINA'),
#  Row(cadenaComercial='CASA LEY'),
#  Row(cadenaComercial='BODEGA GIGANTE'),
#  Row(cadenaComercial='SUPER FARMACIA EL ROSARIO'),
#  Row(cadenaComercial='PESCADERIA JUAREZ'),
#  Row(cadenaComercial='MEGA COMERCIAL MEXICANA'),
#  Row(cadenaComercial='FARMACIA C.M.Q.'),
#  Row(cadenaComercial='FARMA NORTE'),
#  Row(cadenaComercial='EL PITICO'),
#  Row(cadenaComercial='MUEBLERIAS'),
#  Row(cadenaComercial='PAPELERIA NEWBERRY'),
#  Row(cadenaComercial='JUGUETRON'),
#  Row(cadenaComercial='SUPER CHEDRAUI'),
#  Row(cadenaComercial='ALMACENES ZARAGOZA'),
#  Row(cadenaComercial='MERCADO JOSE MARIA PINO SUAREZ'),
#  Row(cadenaComercial='ESCAPARATE'),
#  Row(cadenaComercial='FARMACIA LAS TORRES'),
#  Row(cadenaComercial='JUGUETIBICI'),
#  Row(cadenaComercial='PAPELERIA LAS MARIA LUISAS'),
#  Row(cadenaComercial='UNIFORMES MARINES'),
#  Row(cadenaComercial='PAPELERIA MERCI-CABOS'),
#  Row(cadenaComercial='UNIFORMES LA CIUDAD DE VERACRUZ'),
#  Row(cadenaComercial='LIBRERIA BALANZA'),
#  Row(cadenaComercial='MUEBLERIA FUTURAMA'),
#  Row(cadenaComercial='MINISUPER DANAN'),
#  Row(cadenaComercial='OXXO'),
#  Row(cadenaComercial='MERCADO HIDALGO'),
#  Row(cadenaComercial='UNIFORMES EL GENERAL'),
#  Row(cadenaComercial='FARMACIAS DE SIMILARES'),
#  Row(cadenaComercial='MERCADO CENTRAL DE ACAPULCO'),
#  Row(cadenaComercial='ABASTECEDORA LUMEN'),
#  Row(cadenaComercial='PESCADERIA PUERTO AVENTURA'),
#  Row(cadenaComercial='ZAPATERIA LA LUNA'),
#  Row(cadenaComercial='FARMACIA EMERGENCIAS'),
#  Row(cadenaComercial='ABARROTERA DE BAJA CALIFORNIA'),
#  Row(cadenaComercial='MUEBLES AMERICA'),
#  Row(cadenaComercial='PAPELERIA SNOOPY'),
#  Row(cadenaComercial='MERCADO DEL NORTE'),
#  Row(cadenaComercial='7 ELEVEN'),
#  Row(cadenaComercial='PESCADERIA MARI-MICH'),
#  Row(cadenaComercial='PESCADERA MAC`FISH'),
#  Row(cadenaComercial='ZAPATERIA ZLOP'),
#  Row(cadenaComercial='GAMERS'),
#  Row(cadenaComercial='UNIFORMES DEPORTES JUVENTUD'),
#  Row(cadenaComercial='PESCADERIA BOCA DEL RIO'),
#  Row(cadenaComercial='SUPER SANTA CARMELA'),
#  Row(cadenaComercial='FARMACIA CRUZ BLANCA'),
#  Row(cadenaComercial='UNIFORMES SAAVEDRA'),
#  Row(cadenaComercial='VINOS GIRALDA'),
#  Row(cadenaComercial='UNIFORMES TEJIDOS KEYRI'),
#  Row(cadenaComercial='COMPUCOPIAS'),
#  Row(cadenaComercial='LA CAVA'),
#  Row(cadenaComercial='MINISUPER'),
#  Row(cadenaComercial='MUEBLERIA MI CASA'),
#  Row(cadenaComercial='PAPELERIA CUATITAS GUERRERO'),
#  Row(cadenaComercial='PAPELERIA SAGITARIO'),
#  Row(cadenaComercial='LIBRERIA DEL PARQUE'),
#  Row(cadenaComercial='LIBRERIA BELISARIO CHAVEZ'),
#  Row(cadenaComercial='PAPELERIA AMERICA'),
#  Row(cadenaComercial='HIPER LUMEN'),
#  Row(cadenaComercial='FARMACIA EL CARMEN'),
#  Row(cadenaComercial='PAPELERIA BELPA'),
#  Row(cadenaComercial='LIBRERIA GARCIA'),
#  Row(cadenaComercial='SUPERAMA'),
#  Row(cadenaComercial='MAS FARMACIAS'),
#  Row(cadenaComercial='UNIFORAMA'),
#  Row(cadenaComercial='TRICO PLAZA BELLA'),
#  Row(cadenaComercial='PAPELERIA SALDAÑA'),
#  Row(cadenaComercial='MUEBLERIA EL SURTIDOR DEL HOGAR'),
#  Row(cadenaComercial='TELEBODEGA'),
#  Row(cadenaComercial='PAPELERIA LA PALMA'),
#  Row(cadenaComercial='EDITORIAL IZTACCIHUATL DE MONTERREY'),
#  Row(cadenaComercial='FARMACIA LIQUIS'),
#  Row(cadenaComercial='MERCADO J. JESUS TERAN'),
#  Row(cadenaComercial='FARMACIAS ESTRELLA'),
#  Row(cadenaComercial='TENIS LA BARATA'),
#  Row(cadenaComercial='ALPRECIO'),
#  Row(cadenaComercial='SUPER BLANQUITA'),
#  Row(cadenaComercial='CASA LUZ'),
#  Row(cadenaComercial='PESCADERIA HERMANOS VILLEGAS'),
#  Row(cadenaComercial='LIBRERIA CENTRO'),
#  Row(cadenaComercial='HIPERMERCADO SORIANA'),
#  Row(cadenaComercial='PESCADERIA DELFIN'),
#  Row(cadenaComercial='OFFICE MAX'),
#  Row(cadenaComercial='PAPELERIA DEL AHORRO'),
#  Row(cadenaComercial='COMERC. DE PESCADOS Y MARISCOS VARASA'),
#  Row(cadenaComercial='PAPELERIA TRADICIONAL'),
#  Row(cadenaComercial='FARMACIA YZA'),
#  Row(cadenaComercial='MERCADO PRINCIPAL PEDRO SAINZ DE BARANDA'),
#  Row(cadenaComercial='FARMACIAS LA SALUD'),
#  Row(cadenaComercial='PESCADERIA EL MANGLE'),
#  Row(cadenaComercial='PATROCINIO DE MARIA'),
#  Row(cadenaComercial='BODEGA I.S.S.S.T.E.'),
#  Row(cadenaComercial='CALZADO TELLARI'),
#  Row(cadenaComercial='CASA RIME'),
#  Row(cadenaComercial='LIBRERIA UNIVERSAL'),
#  Row(cadenaComercial='PAPELERIA EL LAPIZ'),
#  Row(cadenaComercial='MUEBLERIA VAIANA'),
#  Row(cadenaComercial='PESCADERIA SANALONA'),
#  Row(cadenaComercial='LIBRERIA DEL SOTANO JUAREZ'),
#  Row(cadenaComercial='MERCADO JUAN ESCUTIA'),
#  Row(cadenaComercial='GRAND MARCHAND'),
#  Row(cadenaComercial='ZAPATERIA GENESIS'),
#  Row(cadenaComercial='PESCADERIA ALEX'),
#  Row(cadenaComercial='UNIFORMES NOVEDADES GLER'),
#  Row(cadenaComercial='ALMACENES EL AGUILA'),
#  Row(cadenaComercial='FARMACIAS ESPECIALIZADAS'),
#  Row(cadenaComercial='FARMACIA UNIVERSITARIA ALEXANDER FLEMING'),
#  Row(cadenaComercial='LIBRERIA PARROQUIAL'),
#  Row(cadenaComercial='CASA VALDEZ'),
#  Row(cadenaComercial='CREACIONES LIZT'),
#  Row(cadenaComercial='VIGO PAPELERIA'),
#  Row(cadenaComercial='LEY EXPRESS'),
#  Row(cadenaComercial='AUTOSERVICIO LOS TREVI'),
#  Row(cadenaComercial='FARMACIA BALANDRA'),
#  Row(cadenaComercial='SUPER ROMA'),
#  Row(cadenaComercial='PESCADERIA SILVA'),
#  Row(cadenaComercial='ELEKTRA'),
#  Row(cadenaComercial='MERCADO GENARO CODINA'),
#  Row(cadenaComercial='EL BUEN PRECIO'),
#  Row(cadenaComercial='PESCADERIA LA MARINERA DEL 23'),
#  Row(cadenaComercial='LIBRERIAS GONVILL'),
#  Row(cadenaComercial='FARMACIA DEL PARQUE DE APIZACO'),
#  Row(cadenaComercial='SUPER PLAZA ARAMBURO'),
#  Row(cadenaComercial='MUEBLERIA RYSE DE MORELIA'),
#  Row(cadenaComercial='MINISUPER 56'),
#  Row(cadenaComercial='FARMACIAS IZA'),
#  Row(cadenaComercial='UNIFORMES DEL SOL'),
#  Row(cadenaComercial='ABARROTES Y VINOS LA FAVORITA'),
#  Row(cadenaComercial='LIBRERIA DRAGONES Y DINOSAURIOS'),
#  Row(cadenaComercial='UNIFORMES EL SURTIDOR DE XOCHIMILCO'),
#  Row(cadenaComercial='FARMACIA SALVATIERRA'),
#  Row(cadenaComercial='BOTICA GUADALUPANA'),
#  Row(cadenaComercial='LA EUROPEA'),
#  Row(cadenaComercial='SUPER GURIERREZ'),
#  Row(cadenaComercial='SUPERMERCADO GONZALEZ'),
#  Row(cadenaComercial='FARMACIAS SIMILARES'),
#  Row(cadenaComercial='FARMACIA LUMING'),
#  Row(cadenaComercial='LICORES DE ANZA'),
#  Row(cadenaComercial='MERCADO AEROPUERTO'),
#  Row(cadenaComercial='ISSSTEY'),
#  Row(cadenaComercial='PESCADERIA BAHIA DE KINO'),
#  Row(cadenaComercial='LIBRERIA UNIVERSITARIA'),
#  Row(cadenaComercial='ABARROTERA GUADALUPANA (FRUTAS)'),
#  Row(cadenaComercial='PESCADERIA S/N'),
#  Row(cadenaComercial='SAN FRANCISCO DE ASIS (ROPA Y TELAS)'),
#  Row(cadenaComercial='UNIFORMES CASA MIMI'),
#  Row(cadenaComercial='FARMACIA VISTA HERMOSA, S.A. DE C.V.'),
#  Row(cadenaComercial='DISTRIBUIDORA EL FLORIDO'),
#  Row(cadenaComercial='MINISUPER MERCADO TOGUZ'),
#  Row(cadenaComercial='LIBRERIA BURREL'),
#  Row(cadenaComercial='ZAPATERIA SANHDAK'),
#  Row(cadenaComercial='MERCADO DEL MAR ZAPOPAN'),
#  Row(cadenaComercial='FARMACIA SANTA ROSA'),
#  Row(cadenaComercial='VIANA'),
#  Row(cadenaComercial='ABARROTES VERO'),
#  Row(cadenaComercial='SUPER SAN FRANCISCO DE ASIS'),
#  Row(cadenaComercial='SUPER CENTRO COMERCIAL EL MIRADOR'),
#  Row(cadenaComercial='UNIFORMES REA'),
#  Row(cadenaComercial='ZAPATERIA AZTECA'),
#  Row(cadenaComercial='MERCADO PUBLICO 5 DE  MAYO'),
#  Row(cadenaComercial='MUEBLES BURA'),
#  Row(cadenaComercial='FARMACIA SAN ISIDRO'),
#  Row(cadenaComercial='SUPER PAPELERA, S.A. DE C.V.'),
#  Row(cadenaComercial='PESCADERIA LA PERLA DEL PACIFICO'),
#  Row(cadenaComercial='ABARROTERA DE TLAXCALA'),
#  Row(cadenaComercial='TRICO (VINATERIA)'),
#  Row(cadenaComercial='PAPELERIA EL RECREO'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS PUERTO NUEVO'),
#  Row(cadenaComercial='LIBRERIA EL LEON'),
#  Row(cadenaComercial='ABARROTES MEXICO'),
#  Row(cadenaComercial='PAPELERIA MORELOS'),
#  Row(cadenaComercial='MARIA LUISA RIVERA FLORES'),
#  Row(cadenaComercial='COMERCIAL UNIVERSITARIA'),
#  Row(cadenaComercial='PESCADERIA ALDAMARI'),
#  Row(cadenaComercial='PESCADOS Y MARSCOS ESTRELLA'),
#  Row(cadenaComercial='UNIFORMES ROA'),
#  Row(cadenaComercial='LIBRERIA PATRIA DE MONTERREY'),
#  Row(cadenaComercial='FARMACIA LA MINIATURA'),
#  Row(cadenaComercial='LIBRERIA  DILIMAD'),
#  Row(cadenaComercial='LIBRERIA DEL CENTRO'),
#  Row(cadenaComercial='PAPELERIA MAPED'),
#  Row(cadenaComercial='GAMES FOR LESS'),
#  Row(cadenaComercial='DROGUERIA MEDINA'),
#  Row(cadenaComercial='DISTRIBUIDORA ESCOLAR Y DE OFICINA J.P.'),
#  Row(cadenaComercial='PAPELERIA ZARATE'),
#  Row(cadenaComercial='PAPELERIA ROSETE ARANDA'),
#  Row(cadenaComercial='FARMACIA ESPECIALIZADA'),
#  Row(cadenaComercial='UNIFORMES BARRERA'),
#  Row(cadenaComercial='MERCADO DIANA LAURA RIOJAS'),
#  Row(cadenaComercial='WAL-MART'),
#  Row(cadenaComercial='LIVERPOOL'),
#  Row(cadenaComercial='VINOS Y LICORES CALAFIA'),
#  Row(cadenaComercial='FARMACIA COMERCIO'),
#  Row(cadenaComercial='COMERCIALIZADORA FARMACEUTICA DE CHS.'),
#  Row(cadenaComercial='FARMACIA Y DROGUERIA TOLUCA'),
#  Row(cadenaComercial='LIBRERIA DEL SOTANO'),
#  Row(cadenaComercial='CORPOVINO'),
#  Row(cadenaComercial='PAPELERIA BACHILLER'),
#  Row(cadenaComercial='PAPELERIA ESCOLAR'),
#  Row(cadenaComercial='DESPENSA DEL HOGAR'),
#  Row(cadenaComercial='PESCADERIA LIZ DEL MAR'),
#  Row(cadenaComercial='ZAPATERIAS 3 HERMANOS'),
#  Row(cadenaComercial='UNIFORMES EL ARTILLERO'),
#  Row(cadenaComercial='COMPAÑIA PAPELERA DE MORELOS'),
#  Row(cadenaComercial='FARMACIAS DEL AHORRO'),
#  Row(cadenaComercial='PESCADERIA YURIDIA'),
#  Row(cadenaComercial='FARMAPRONTO'),
#  Row(cadenaComercial='BODEGA COMERCIAL MEXICANA'),
#  Row(cadenaComercial='MUEBLERIA GUADALUPANA'),
#  Row(cadenaComercial='LA BARATA'),
#  Row(cadenaComercial='LIBRERIA AMERICAN BOOK STORE'),
#  Row(cadenaComercial='OPTIVOSA'),
#  Row(cadenaComercial='SEARS ROEBUCK DE MEXICO'),
#  Row(cadenaComercial='LA VIÑA DEL VINO'),
#  Row(cadenaComercial='FARMACIAS GUELAGUETZA'),
#  Row(cadenaComercial='PAPELERIA OFIX'),
#  Row(cadenaComercial='UNIFORMES ESCOLARES ROSY'),
#  Row(cadenaComercial='VINOS BONATERRA'),
#  Row(cadenaComercial='LEY (AUTOSERVICIO)'),
#  Row(cadenaComercial='TENIS COMERCIAL JID'),
#  Row(cadenaComercial='PAPELERIA CASA MARCHARD'),
#  Row(cadenaComercial='PESCADERIA BARRA DE NAVIDAD'),
#  Row(cadenaComercial='LIBRERIA EL BACHILLER'),
#  Row(cadenaComercial='PESCADERIAS'),
#  Row(cadenaComercial='DISTRIBUIDORA QUERETANA DE MEDICAMENTOS'),
#  Row(cadenaComercial='FARMACIA DEL AHORRO'),
#  Row(cadenaComercial='MERCANTIL VINATERA'),
#  Row(cadenaComercial='PAPELERIA EL AGUILA'),
#  Row(cadenaComercial='PESCADERIA GUERRERO'),
#  Row(cadenaComercial='PAPELERIA TONY'),
#  Row(cadenaComercial='FARMACIA LA LUZ'),
#  Row(cadenaComercial='MUEBLERIA MAYA'),
#  Row(cadenaComercial='ZAPATERIA DESTROYER'),
#  Row(cadenaComercial='MUEBLERIA MILENIO'),
#  Row(cadenaComercial='SUPERMERCADOS LEY'),
#  Row(cadenaComercial='FARMACIA SIMILAR'),
#  Row(cadenaComercial='MERCADO MARIA LUISA'),
#  Row(cadenaComercial='PAPELERIAS CUAUHTEMOC'),
#  Row(cadenaComercial='FARMACIA PARIS'),
#  Row(cadenaComercial='PAPELERIA LA POPULAR'),
#  Row(cadenaComercial='MUEBLERIA DEL SOL'),
#  Row(cadenaComercial='LIDERES SIMILARES'),
#  Row(cadenaComercial='PAPELERIA LA MICHOACANA'),
#  Row(cadenaComercial='LA DIVINA'),
#  Row(cadenaComercial='UNIFORMES COLIBRI'),
#  Row(cadenaComercial='FARMACIA GUADALAJARA'),
#  Row(cadenaComercial='I.M.S.S.'),
#  Row(cadenaComercial='TRICO RELOJ'),
#  Row(cadenaComercial='ELECTROMUEBLES'),
#  Row(cadenaComercial='PAPELERIA OFFICE SERVICE'),
#  Row(cadenaComercial='I.S.S.S.T.E.'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS BARI'),
#  Row(cadenaComercial='CIMACO'),
#  Row(cadenaComercial='LIBRERIA DE CRISTAL'),
#  Row(cadenaComercial='DIST. DE ABARROTES LA RIVERA S.A.'),
#  Row(cadenaComercial='ALSUPER STORE'),
#  Row(cadenaComercial='PESCADERIA LINDO SINALOA'),
#  Row(cadenaComercial='LA VIGA DE MORELOS'),
#  Row(cadenaComercial='TORTILLERIAS TRADICIONALES'),
#  Row(cadenaComercial='ZAPATERIA RODRIGUEZ'),
#  Row(cadenaComercial='FARMACIAS DEL PUEBLO'),
#  Row(cadenaComercial='LIBRERIA HIDALGO'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS MIRAMAR'),
#  Row(cadenaComercial='MERZA PACK'),
#  Row(cadenaComercial='LA COLONIAL'),
#  Row(cadenaComercial='MUNDO DE LOS MARISCOS'),
#  Row(cadenaComercial='ADOSA'),
#  Row(cadenaComercial='SANBORN S HNOS.'),
#  Row(cadenaComercial='FARMACIA SANTA CRUZ'),
#  Row(cadenaComercial='LIBRERIA Y PAPELERIA DE SANCHO PANZA'),
#  Row(cadenaComercial='PAPELERIA LA GOMA'),
#  Row(cadenaComercial='MINISUPER CONCHALITO'),
#  Row(cadenaComercial='SUPERETTE'),
#  Row(cadenaComercial='MUEBLERIA ALMACENES DEL NORTE'),
#  Row(cadenaComercial='FARMACIAS VYR'),
#  Row(cadenaComercial='PAPELERIA MANZANILLO'),
#  Row(cadenaComercial='MERCADO GUADALUPE'),
#  Row(cadenaComercial='FARMACIA DEL CENTRO'),
#  Row(cadenaComercial='CORPOVINO MEJIA'),
#  Row(cadenaComercial='UNIFORMES MAKALI'),
#  Row(cadenaComercial='OPERADORA PRISSA'),
#  Row(cadenaComercial='COLCHONES Y MUEBLES DE CAMPECHE'),
#  Row(cadenaComercial='MUEBLERIA PATJANE CEJA'),
#  Row(cadenaComercial='ISSSTEZAC'),
#  Row(cadenaComercial='cadenaComercial'),
#  Row(cadenaComercial='FARMATODO'),
#  Row(cadenaComercial='ZAPATERIA EL GLOBITO'),
#  Row(cadenaComercial='PAPELERIA LA MARIPOSA'),
#  Row(cadenaComercial='PESCADERIA HERMANOS LUNA'),
#  Row(cadenaComercial='MARISCOS LA PLAYITA'),
#  Row(cadenaComercial='FARMACIA DE DOCTOR DESCUENTO'),
#  Row(cadenaComercial='BMART'),
#  Row(cadenaComercial='MINISUPER MICKY'),
#  Row(cadenaComercial='PAPELERIA LAPICITO'),
#  Row(cadenaComercial='MERCADO MALIBRAN'),
#  Row(cadenaComercial='ALVA PAPELERIA'),
#  Row(cadenaComercial='VINATERIA GRUPO ARCE'),
#  Row(cadenaComercial='VINOS Y LICORES EL TECOLOTE'),
#  Row(cadenaComercial='FARMACIA SAN JUAN'),
#  Row(cadenaComercial='ALSUPER'),
#  Row(cadenaComercial='ABARROTES LA VIOLETA'),
#  Row(cadenaComercial='MEGA COMERCIAL'),
#  Row(cadenaComercial='ABARROTERA SANCHEZ'),
#  Row(cadenaComercial='UNIFORMES CASA CASTILLA'),
#  Row(cadenaComercial='SORIANA PLUS'),
#  Row(cadenaComercial='LIBRERIA PORRUA'),
#  Row(cadenaComercial='LIBRERIA LA GRANDE'),
#  Row(cadenaComercial='ZAPATERIA LA PERLA'),
#  Row(cadenaComercial='UNIFORMES ESCOLARES TEJIDOS NAVA'),
#  Row(cadenaComercial='SUPER AKI'),
#  Row(cadenaComercial='FARMACIA KINO'),
#  Row(cadenaComercial='SURTIFIRME S.A. DE C.V. (HOGAR & MAS)'),
#  Row(cadenaComercial='PAPELERIA EL ALMACEN'),
#  Row(cadenaComercial='PAPELERIA FARAH'),
#  Row(cadenaComercial='SORIANA EXPRESS'),
#  Row(cadenaComercial='PAPELERIA GODI'),
#  Row(cadenaComercial='VINATERIA LA PLAYA'),
#  Row(cadenaComercial='ANDA FARMACIAS'),
#  Row(cadenaComercial='DANIEL S UNIFORMES'),
#  Row(cadenaComercial='FARMACIA LA GUADALUPANA'),
#  Row(cadenaComercial='ALMACENES RODRIGUEZ'),
#  Row(cadenaComercial='OFFICE CENTER'),
#  Row(cadenaComercial='UNIFORMES ESCOLARES Y DEPORTIVOS'),
#  Row(cadenaComercial='SUPER SANCHEZ'),
#  Row(cadenaComercial='ABARROTES ARTES'),
#  Row(cadenaComercial='JULIO GUADALUPE SANCHEZ AGUILAR'),
#  Row(cadenaComercial='ORZO ARTICULOS ESCOLARES Y DE OFICINA'),
#  Row(cadenaComercial='PESCADERIA DEL FUERTE'),
#  Row(cadenaComercial='LIBRERIA UNIVERSO XXI'),
#  Row(cadenaComercial='MUEBLERIA VALDEZ BALUARTE'),
#  Row(cadenaComercial='TENIS SANTIAGO SPORT'),
#  Row(cadenaComercial='PAPELERIA PAQUIN'),
#  Row(cadenaComercial='TIENDA MAMBO'),
#  Row(cadenaComercial='PAPELERIA LA CULTURA'),
#  Row(cadenaComercial='COPPEL'),
#  Row(cadenaComercial='LIBRERIA MADERO DE MORELIA'),
#  Row(cadenaComercial='LICORES TUZOS'),
#  Row(cadenaComercial='FARMACIA LA UNION'),
#  Row(cadenaComercial='FARMACIA POPULAR ROMAN'),
#  Row(cadenaComercial='FARMACIA SAN MIGUEL'),
#  Row(cadenaComercial='CENTRO LIBRERO DE MORELIA'),
#  Row(cadenaComercial='PAPELERIA DEL NORTE'),
#  Row(cadenaComercial='LIBRERIA EL TINTERO'),
#  Row(cadenaComercial='PAPELERIA LA ESCOLAR'),
#  Row(cadenaComercial='PAPELERIA LAPI'),
#  Row(cadenaComercial='H.E.B.'),
#  Row(cadenaComercial='FARMACIA ZAPOTLAN'),
#  Row(cadenaComercial='PESCADERIA ALVAREZ'),
#  Row(cadenaComercial='PAPELERIA LA ORTOFONICA'),
#  Row(cadenaComercial='AUTOSERVICIO ZARAGOZA'),
#  Row(cadenaComercial='FARMACIA ISSEG'),
#  Row(cadenaComercial='EL SALTO SIN NOMBRE'),
#  Row(cadenaComercial='UNIFORMES BEKAMEX'),
#  Row(cadenaComercial='ALMACENES GARCIA'),
#  Row(cadenaComercial='GRUPO LIBRERO DEL SURESTE'),
#  Row(cadenaComercial='CHEDRAUI'),
#  Row(cadenaComercial='UNIFORMES CASA TINO'),
#  Row(cadenaComercial='FARMACIA FLEMINGO'),
#  Row(cadenaComercial='GALA DISEÑO EN MUEBLES, S.A. DE C.V.'),
#  Row(cadenaComercial='PESCADERIA FALUA'),
#  Row(cadenaComercial='FARMACIA NUEVA VIDA'),
#  Row(cadenaComercial='PESCADERIA EL CHARAL'),
#  Row(cadenaComercial='JUGUETERIA LA PALMA'),
#  Row(cadenaComercial='MERCADO DE ABASTOS'),
#  Row(cadenaComercial='MINISUPER AZTECA'),
#  Row(cadenaComercial='LIBRERIA ZACATECAS'),
#  Row(cadenaComercial='LIBRERIA MADERO'),
#  Row(cadenaComercial='UNIFORMES CREACIONES PIÑA'),
#  Row(cadenaComercial='LA ESTRELLITA'),
#  Row(cadenaComercial='MUEBLES DEL ANGEL'),
#  Row(cadenaComercial='PAPELERIA NET'),
#  Row(cadenaComercial='AS FARMACIAS'),
#  Row(cadenaComercial='PAPELERIA LA NORMAL'),
#  Row(cadenaComercial='LIBRERIA ZARAGOZA'),
#  Row(cadenaComercial='FARMACIA TORRE MEDICA'),
#  Row(cadenaComercial='PESCADERIA GAMBERO'),
#  Row(cadenaComercial='PALACIO DEL MUEBLE'),
#  Row(cadenaComercial='FARMACIA DEL HOSPITAL'),
#  Row(cadenaComercial='OPERADORA MERCO'),
#  Row(cadenaComercial='MINISUPER CHARLY'),
#  Row(cadenaComercial='FARMACIA DROGUERIAS MANZANO'),
#  Row(cadenaComercial='MARISCOS PAPILLON'),
#  Row(cadenaComercial='PAPELERIA GARY'),
#  Row(cadenaComercial='UNIFORMES CASA CRUZ'),
#  Row(cadenaComercial='SUPER SUAREZ'),
#  Row(cadenaComercial='NOVEDADES CLARA'),
#  Row(cadenaComercial='PAPELERIA EL CEDRO'),
#  Row(cadenaComercial='PAPELERIA VAZQUEZ HERMANOS Y COMPAÑIA'),
#  Row(cadenaComercial='MÓNICA ESTEFANIA ORTIZ ZORRILLA'),
#  Row(cadenaComercial='COMERCIAL MEXICANA'),
#  Row(cadenaComercial='MUEBLERIAS PORTILLO'),
#  Row(cadenaComercial='PAPELERIA MADERO'),
#  Row(cadenaComercial='AUTOSERVICIO POWIS'),
#  Row(cadenaComercial='MERCADO EL MESON ESTRELLA'),
#  Row(cadenaComercial='TIENDAS GARIS'),
#  Row(cadenaComercial='PAPELERIA DEL PARQUE'),
#  Row(cadenaComercial='MAS BODEGA'),
#  Row(cadenaComercial='FARMACIA PUREX'),
#  Row(cadenaComercial='SUMESA'),
#  Row(cadenaComercial='PAPELERIA GARCIA'),
#  Row(cadenaComercial='MERCADO EMILIO SANCHEZ PIEDRAS'),
#  Row(cadenaComercial='MI BODEGA AURRERA'),
#  Row(cadenaComercial='PAPELERIA TLAXACALA'),
#  Row(cadenaComercial='ABARROTERA MONTERREY'),
#  Row(cadenaComercial='GALA'),
#  Row(cadenaComercial='SUPER DEL NORTE'),
#  Row(cadenaComercial='LA PERLA ESCOLAR DE NAYARIT S.A. DE C.V.'),
#  Row(cadenaComercial='ZARAGOZA MUEBLES'),
#  Row(cadenaComercial='LIBRERIA IBAÑEZ'),
#  Row(cadenaComercial='VINOS Y LICORES EL GALLITO'),
#  Row(cadenaComercial='MUEBLERIA EL GRAN SALTO'),
#  Row(cadenaComercial='FARMACIA MODERNA'),
#  Row(cadenaComercial='MERCADO DEL MAR FELIPE ANGELES HIGUERILL'),
#  Row(cadenaComercial='CASA MORALES'),
#  Row(cadenaComercial='PESCADOS Y MARISCOS SANDRA'),
#  Row(cadenaComercial='TIENDAS CONTINO'),
#  Row(cadenaComercial='UNIFORMES ERICK'),
#  Row(cadenaComercial='ABARROTES SUPER CABRERA CLASS'),
#  Row(cadenaComercial='PESCADERIA LA JAIBA'),
#  Row(cadenaComercial='MEGA ELEKTRA'),
#  Row(cadenaComercial='NOVEDADES OLAGUE S.A. DE C.V.'),
#  Row(cadenaComercial='EDITORIAL TRILLAS'),
#  Row(cadenaComercial='ZAPATERIA LAS VEGAS'),
#  Row(cadenaComercial='MERCADO MUNICIPAL BENITO JUAREZ'),
#  Row(cadenaComercial='LIBRERIA CIENCIA Y CONTEXTO'),
#  Row(cadenaComercial='FARMACIA DE MAS AHORRO'),
#  Row(cadenaComercial='SUPER CHE'),
#  Row(cadenaComercial='UNIFORMES ACOSTA'),
#  Row(cadenaComercial='LIBRERIA EL LIBRO MAGICO'),
#  Row(cadenaComercial='CENTRO LIBRERO DE PUEBLA'),
#  Row(cadenaComercial='TENIS LA LUNA'),
#  Row(cadenaComercial='FARMACIA MEDIMAX'),
#  Row(cadenaComercial='EKAR DE GAS'),
#  Row(cadenaComercial='MINISUPER LA VAQUITA'),
#  Row(cadenaComercial='APARATOS Y MUEBLES DE MORELIA'),
#  Row(cadenaComercial='PESCADERIA MUÑOZ'),
#  Row(cadenaComercial='UNIFORMES NOVEDADES ROSITA'),
#  Row(cadenaComercial='FARMACIA PEY PHARMA'),
#  Row(cadenaComercial='PROVEEDORA DE OFICINAS'),
#  Row(cadenaComercial='SUPER CITY'),
#  Row(cadenaComercial='LA ARGENTINA'),
#  Row(cadenaComercial='MERCADO PUBLICO'),
#  Row(cadenaComercial='PAPELERIA ZERO')]

# %%
len(lst_2) #cadenaComercial, None
# Out:
# 706

# %% [markdown]
# 704 cadenas comerciales están siendo monitoreadas porque cadenaComercial y None no son cadenas comerciales

# %% [markdown]
# d. ¿Cómo podrías determinar la calidad de los datos? ¿Detectaste algún tipo de
# inconsistencia o error en la fuente?

# %%
df.printSchema()
# Out:
# root
#  |-- producto: string (nullable = true)
#  |-- presentacion: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- catalogo: string (nullable = true)
#  |-- precio: float (nullable = true)
#  |-- fechaRegistro: string (nullable = true)
#  |-- cadenaComercial: string (nullable = true)
#  |-- giro: string (nullable = true)
#  |-- nombreComercial: string (nullable = true)
#  |-- direccion: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- municipio: string (nullable = true)
#  |-- latitud: float (nullable = true)
#  |-- longitud: float (nullable = true)

# %%
from pyspark.sql.functions import isnan, when, count, col

df.select([count(when(col(c).isNull(), c)).alias(c) for c in 
           df.columns]).toPandas().T
# Out:
#                        0
# producto               0
# presentacion           0
# marca                  0
# categoria         887338
# catalogo             228
# precio                20
# fechaRegistro          0
# cadenaComercial     1184
# giro                 287
# nombreComercial        0
# direccion              0
# estado             15054
# municipio          15054
# latitud          1167239
# longitud         1167107

# %%
df = df.filter((df.estado.isNotNull()) | (df.cadenaComercial.isNotNull()))

# %%
df.select([count(when(col(c).isNull(), c)).alias(c) for c in 
           df.columns]).toPandas().T
# Out:
#                        0
# producto               0
# presentacion           0
# marca                  0
# categoria         887338
# catalogo             228
# precio                20
# fechaRegistro          0
# cadenaComercial        0
# giro                 287
# nombreComercial        0
# direccion              0
# estado                 0
# municipio              0
# latitud          1165437
# longitud         1165305

# %% [markdown]
# Hay registros en la columna de categoría que no son categorías al igual que en la de cadena comercial. Hay nullos en 9 de las 15 columnas.

# %% [markdown]
# e. ¿Cuáles son los productos más monitoreados en cada entidad?

# %%
lst_3 = df.groupBy("estado").count().orderBy("count").select("estado").collect()

# %%
lst_3
# Out:
# [Row(estado='estado'),
#  Row(estado=' ESQ. SUR 125"'),
#  Row(estado=' COL. EDUARDO GUERRA'),
#  Row(estado='MORELOS'),
#  Row(estado='NAYARIT'),
#  Row(estado='GUERRERO'),
#  Row(estado='CHIAPAS'),
#  Row(estado='SAN LUIS POTOSÍ'),
#  Row(estado='DURANGO'),
#  Row(estado='CAMPECHE'),
#  Row(estado='AGUASCALIENTES'),
#  Row(estado='VERACRUZ DE IGNACIO DE LA LLAVE'),
#  Row(estado='CHIHUAHUA'),
#  Row(estado='BAJA CALIFORNIA SUR'),
#  Row(estado='HIDALGO'),
#  Row(estado='OAXACA'),
#  Row(estado='COLIMA'),
#  Row(estado='TAMAULIPAS'),
#  Row(estado='BAJA CALIFORNIA'),
#  Row(estado='ZACATECAS'),
#  Row(estado='COAHUILA DE ZARAGOZA'),
#  Row(estado='QUERÉTARO'),
#  Row(estado='SONORA'),
#  Row(estado='SINALOA'),
#  Row(estado='TABASCO'),
#  Row(estado='PUEBLA'),
#  Row(estado='QUINTANA ROO'),
#  Row(estado='TLAXCALA'),
#  Row(estado='MICHOACÁN DE OCAMPO'),
#  Row(estado='YUCATÁN'),
#  Row(estado='GUANAJUATO'),
#  Row(estado='NUEVO LEÓN'),
#  Row(estado='JALISCO'),
#  Row(estado='MÉXICO'),
#  Row(estado='DISTRITO FEDERAL')]

# %%
lst_3=lst_3[3:]

# %%
lst_3
# Out:
# [Row(estado='MORELOS'),
#  Row(estado='NAYARIT'),
#  Row(estado='GUERRERO'),
#  Row(estado='CHIAPAS'),
#  Row(estado='SAN LUIS POTOSÍ'),
#  Row(estado='DURANGO'),
#  Row(estado='CAMPECHE'),
#  Row(estado='AGUASCALIENTES'),
#  Row(estado='VERACRUZ DE IGNACIO DE LA LLAVE'),
#  Row(estado='CHIHUAHUA'),
#  Row(estado='BAJA CALIFORNIA SUR'),
#  Row(estado='HIDALGO'),
#  Row(estado='OAXACA'),
#  Row(estado='COLIMA'),
#  Row(estado='TAMAULIPAS'),
#  Row(estado='BAJA CALIFORNIA'),
#  Row(estado='ZACATECAS'),
#  Row(estado='COAHUILA DE ZARAGOZA'),
#  Row(estado='QUERÉTARO'),
#  Row(estado='SONORA'),
#  Row(estado='SINALOA'),
#  Row(estado='TABASCO'),
#  Row(estado='PUEBLA'),
#  Row(estado='QUINTANA ROO'),
#  Row(estado='TLAXCALA'),
#  Row(estado='MICHOACÁN DE OCAMPO'),
#  Row(estado='YUCATÁN'),
#  Row(estado='GUANAJUATO'),
#  Row(estado='NUEVO LEÓN'),
#  Row(estado='JALISCO'),
#  Row(estado='MÉXICO'),
#  Row(estado='DISTRITO FEDERAL')]

# %%
lst_4=[]
for i in range(len(lst_3)):
    lst_4.append(str(lst_3[i]).split("'")[1])

# %%
len(lst_4)
# Out:
# 32

# %%
df_corregida = df.filter(col('estado').isin(lst_4))

# %%
print(df.count(),df_corregida.count()
# Out:
# 62530715 62501145

# %%
lst_5=df_corregida.groupBy("estado").count().orderBy("count").select("estado").collect()

# %%
len(lst_5)
# Out:
# 32

# %%
df4=df_corregida.groupBy("estado","producto").count().sort('count',ascending=False)

# %%
for i in range(len(lst_5)):
    df4.filter(df4.estado == str(lst_5[i]).split("'")[1]).show(3)
# Out:
# +-------+--------+-----+
# | estado|producto|count|
# +-------+--------+-----+
# |MORELOS|REFRESCO| 9632|
# |MORELOS|     FUD| 6909|
# +-------+--------+-----+
# only showing top 2 rows
#
# +-------+---------+-----+
# | estado| producto|count|
# +-------+---------+-----+
# |NAYARIT| REFRESCO| 8003|
# |NAYARIT|PANTALLAS| 7083|
# +-------+---------+-----+
# only showing top 2 rows
#
# +--------+--------+-----+
# |  estado|producto|count|
# +--------+--------+-----+
# |GUERRERO|REFRESCO| 8932|
# |GUERRERO|     FUD| 8846|
# +--------+--------+-----+
# only showing top 2 rows
#
# +-------+--------+-----+
# | estado|producto|count|
# +-------+--------+-----+
# |CHIAPAS|REFRESCO|14452|
# |CHIAPAS|     FUD|10417|
# +-------+--------+-----+
# only showing top 2 rows
#
# +---------------+---------+-----+
# |         estado| producto|count|
# +---------------+---------+-----+
# |SAN LUIS POTOSÍ|      FUD|10164|
# |SAN LUIS POTOSÍ|PANTALLAS| 8662|
# +---------------+---------+-----+
# only showing top 2 rows
#
# +-------+-----------------+-----+
# | estado|         producto|count|
# +-------+-----------------+-----+
# |DURANGO|DETERGENTE P/ROPA| 9696|
# |DURANGO|        LAVADORAS| 9644|
# +-------+-----------------+-----+
# only showing top 2 rows
#
# +--------+--------+-----+
# |  estado|producto|count|
# +--------+--------+-----+
# |CAMPECHE|     FUD|12960|
# |CAMPECHE|REFRESCO|11333|
# +--------+--------+-----+
# only showing top 2 rows
#
# +--------------+-----------------+-----+
# |        estado|         producto|count|
# +--------------+-----------------+-----+
# |AGUASCALIENTES|              FUD|12005|
# |AGUASCALIENTES|DETERGENTE P/ROPA|10188|
# +--------------+-----------------+-----+
# only showing top 2 rows
#
# +--------------------+--------------------+-----+
# |              estado|            producto|count|
# +--------------------+--------------------+-----+
# |VERACRUZ DE IGNAC...|            REFRESCO|14576|
# |VERACRUZ DE IGNAC...|LECHE ULTRAPASTEU...|12051|
# +--------------------+--------------------+-----+
# only showing top 2 rows
#
# +---------+-----------------+-----+
# |   estado|         producto|count|
# +---------+-----------------+-----+
# |CHIHUAHUA|DETERGENTE P/ROPA|15982|
# |CHIHUAHUA|              FUD|14348|
# +---------+-----------------+-----+
# only showing top 2 rows
#
# +-------------------+--------+-----+
# |             estado|producto|count|
# +-------------------+--------+-----+
# |BAJA CALIFORNIA SUR|REFRESCO|27770|
# |BAJA CALIFORNIA SUR|     FUD|17776|
# +-------------------+--------+-----+
# only showing top 2 rows
#
# +-------+---------+-----+
# | estado| producto|count|
# +-------+---------+-----+
# |HIDALGO| REFRESCO|18137|
# |HIDALGO|LAVADORAS|16519|
# +-------+---------+-----+
# only showing top 2 rows
#
# +------+--------------------+-----+
# |estado|            producto|count|
# +------+--------------------+-----+
# |OAXACA|LECHE ULTRAPASTEU...|18078|
# |OAXACA|            REFRESCO|14501|
# +------+--------------------+-----+
# only showing top 2 rows
#
# +------+--------------------+-----+
# |estado|            producto|count|
# +------+--------------------+-----+
# |COLIMA|   DETERGENTE P/ROPA|17193|
# |COLIMA|LECHE ULTRAPASTEU...|14425|
# +------+--------------------+-----+
# only showing top 2 rows
#
# +----------+--------+-----+
# |    estado|producto|count|
# +----------+--------+-----+
# |TAMAULIPAS|REFRESCO|22457|
# |TAMAULIPAS|     FUD|21113|
# +----------+--------+-----+
# only showing top 2 rows
#
# +---------------+-----------------+-----+
# |         estado|         producto|count|
# +---------------+-----------------+-----+
# |BAJA CALIFORNIA|         REFRESCO|37243|
# |BAJA CALIFORNIA|DETERGENTE P/ROPA|23395|
# +---------------+-----------------+-----+
# only showing top 2 rows
#
# +---------+--------------------+-----+
# |   estado|            producto|count|
# +---------+--------------------+-----+
# |ZACATECAS|   DETERGENTE P/ROPA|20884|
# |ZACATECAS|LECHE ULTRAPASTEU...|17309|
# +---------+--------------------+-----+
# only showing top 2 rows
#
# +--------------------+--------+-----+
# |              estado|producto|count|
# +--------------------+--------+-----+
# |COAHUILA DE ZARAGOZA|     FUD|28613|
# |COAHUILA DE ZARAGOZA|REFRESCO|26889|
# +--------------------+--------+-----+
# only showing top 2 rows
#
# +---------+--------------------+-----+
# |   estado|            producto|count|
# +---------+--------------------+-----+
# |QUERÉTARO|LECHE ULTRAPASTEU...|27868|
# |QUERÉTARO|   DETERGENTE P/ROPA|26700|
# +---------+--------------------+-----+
# only showing top 2 rows
#
# +------+-----------------+-----+
# |estado|         producto|count|
# +------+-----------------+-----+
# |SONORA|         REFRESCO|34731|
# |SONORA|DETERGENTE P/ROPA|31997|
# +------+-----------------+-----+
# only showing top 2 rows
#
# +-------+-----------------+-----+
# | estado|         producto|count|
# +-------+-----------------+-----+
# |SINALOA|         REFRESCO|33115|
# |SINALOA|DETERGENTE P/ROPA|27177|
# +-------+-----------------+-----+
# only showing top 2 rows
#
# +-------+-----------------+-----+
# | estado|         producto|count|
# +-------+-----------------+-----+
# |TABASCO|         REFRESCO|28754|
# |TABASCO|DETERGENTE P/ROPA|26431|
# +-------+-----------------+-----+
# only showing top 2 rows
#
# +------+---------+-----+
# |estado| producto|count|
# +------+---------+-----+
# |PUEBLA| REFRESCO|31597|
# |PUEBLA|LAVADORAS|27076|
# +------+---------+-----+
# only showing top 2 rows
#
# +------------+--------+-----+
# |      estado|producto|count|
# +------------+--------+-----+
# |QUINTANA ROO|     FUD|34846|
# |QUINTANA ROO|REFRESCO|34367|
# +------------+--------+-----+
# only showing top 2 rows
#
# +--------+-----------------+-----+
# |  estado|         producto|count|
# +--------+-----------------+-----+
# |TLAXCALA|         REFRESCO|43904|
# |TLAXCALA|DETERGENTE P/ROPA|41398|
# +--------+-----------------+-----+
# only showing top 2 rows
#
# +-------------------+-----------------+-----+
# |             estado|         producto|count|
# +-------------------+-----------------+-----+
# |MICHOACÁN DE OCAMPO|DETERGENTE P/ROPA|40144|
# |MICHOACÁN DE OCAMPO|         REFRESCO|38016|
# +-------------------+-----------------+-----+
# only showing top 2 rows
#
# +-------+--------------------+-----+
# | estado|            producto|count|
# +-------+--------------------+-----+
# |YUCATÁN|LECHE ULTRAPASTEU...|35991|
# |YUCATÁN|   DETERGENTE P/ROPA|33390|
# +-------+--------------------+-----+
# only showing top 2 rows
#
# +----------+-----------------+-----+
# |    estado|         producto|count|
# +----------+-----------------+-----+
# |GUANAJUATO|         REFRESCO|49441|
# |GUANAJUATO|DETERGENTE P/ROPA|36618|
# +----------+-----------------+-----+
# only showing top 2 rows
#
# +----------+-----------------+-----+
# |    estado|         producto|count|
# +----------+-----------------+-----+
# |NUEVO LEÓN|DETERGENTE P/ROPA|50307|
# |NUEVO LEÓN|         REFRESCO|49592|
# +----------+-----------------+-----+
# only showing top 2 rows
#
# +-------+--------------------+-----+
# | estado|            producto|count|
# +-------+--------------------+-----+
# |JALISCO|            REFRESCO|81718|
# |JALISCO|LECHE ULTRAPASTEU...|81149|
# +-------+--------------------+-----+
# only showing top 2 rows
#
# +------+--------+------+
# |estado|producto| count|
# +------+--------+------+
# |MÉXICO|REFRESCO|194939|
# |MÉXICO|     FUD|149141|
# +------+--------+------+
# only showing top 2 rows
#
# +----------------+--------+------+
# |          estado|producto| count|
# +----------------+--------+------+
# |DISTRITO FEDERAL|REFRESCO|287463|
# |DISTRITO FEDERAL|     FUD|207569|
# +----------------+--------+------+
# only showing top 2 rows

# %% [markdown]
# En la tabla se observa los productos más monitoreados en cada entidad. Por ejemplo, en el DISTRITO FEDERAL el refresco y fud son los más monitoreados.

# %% [markdown]
# f. ¿Cuál es la cadena comercial con mayor variedad de productos monitoreados?

# %%
df5=df_corregida.groupBy("cadenaComercial").agg(countDistinct("producto")).sort("count(producto)",ascending=False)

# %%
df5.show()
# Out:
# +--------------------+---------------+
# |     cadenaComercial|count(producto)|
# +--------------------+---------------+
# |             SORIANA|           1059|
# |            WAL-MART|           1051|
# |MEGA COMERCIAL ME...|           1049|
# |  COMERCIAL MEXICANA|           1036|
# |            CHEDRAUI|           1026|
# |     MERCADO SORIANA|           1024|
# |      BODEGA AURRERA|           1012|
# |HIPERMERCADO SORIANA|           1006|
# |              H.E.B.|           1001|
# |        SORIANA PLUS|            999|
# |       SORIANA SUPER|            996|
# |BODEGA COMERCIAL ...|            979|
# |        I.S.S.S.T.E.|            937|
# |            SUPERAMA|            936|
# |              S MART|            851|
# |SUPERMERCADOS SAN...|            849|
# |              SUMESA|            848|
# |         CITY MARKET|            844|
# |FARMACIA GUADALAJARA|            819|
# |            CASA LEY|            808|
# +--------------------+---------------+
# only showing top 20 rows

# %% [markdown]
# La cadena comercial con mayor variedad de productos monitoreados es SORIANA
